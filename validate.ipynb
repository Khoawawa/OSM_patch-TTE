# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import pickle

# %%
poi_json = 'mydata/poi_cell/porto_pois_0.001_5.json'
with open(poi_json, 'r') as f:
    poi_data = json.load(f)
print(f"Total POI cells: {len(poi_data)}")
max_cx = max(v['cell_id'][0] for v in poi_data.values())
max_cy = max(v['cell_id'][1] for v in poi_data.values())
print(f"Max cell_x: {max_cx}, Max cell_y: {max_cy}")
T = 7
H = max_cx +1
W = max_cy +1
# Out:
# Total POI cells: 6480
# Max cell_x: 47, Max cell_y: 134
