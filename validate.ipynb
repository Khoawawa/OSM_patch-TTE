# %%
import numpy as np
import pickle
import os

# %%
with open(os.path.join('mydata/network_porto/porto_edges_new_simplify.pkl'), 'rb') as f:
        edgeinfo = pickle.load(f)
with open(os.path.join('mydata/network_porto/porto_nodes_new.pkl'), 'rb') as f:
    nodeinfo = pickle.load(f)

# %%
print(list(nodeinfo.items())[0])
# Out:
# ('25503936', (-8.6406364, 41.1660713, 3.0))
